# %% [markdown]
# <a href="https://colab.research.google.com/github/surajkale970-cmyk/ML121/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("SGI");
# Out:
# SGI
