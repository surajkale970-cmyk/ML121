# %% [markdown]
# <a href="https://colab.research.google.com/github/surajkale970-cmyk/ML121/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
#data
X=np.array([1,2,3,4,5], dtype=float)
y=np.array([2,4,5,4,5], dtype=float)

# %%
#initial values
b0=0
b1=0
learning_rate=0.01
epochs=1000
n=len(X)

# %%
#Gradient Descent
for i in range(epochs):

    Y_pred = b0 + b1 * X


    db0 = (-2/n) * np.sum(y - Y_pred)
    db1 = (-2/n) * np.sum(X * (y - Y_pred))

    b0 = b0 - learning_rate * db0
    b1 = b1 - learning_rate * db1

print("b0 =", b0)
print("b1 =", b1)

print("Regression Equation:")
print("Y =", b0, "+", b1, "X")
# Out:
# b0 = 2.1978394441186833
# b1 = 0.6005984393344997
# Regression Equation:
# Y = 2.1978394441186833 + 0.6005984393344997 X
