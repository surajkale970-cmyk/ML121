# %% [markdown]
# <a href="https://colab.research.google.com/github/surajkale970-cmyk/ML121/blob/main/titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Load dataset
data = pd.read_csv("/content/train_and_test2.csv")

# Input (X) and Output (Y)
X = data[["Age"]]
y = data["Fare"]

# Create Linear Regression model
model = LinearRegression()

# Train the model
model.fit(X, y)

# Predict values
y_pred = model.predict(X)

# Print coefficients
print("Intercept (b0):", model.intercept_)
print("Slope (b1):", model.coef_[0])

# Plot original data
plt.scatter(X, y, label="Actual Data")

# Plot regression line
plt.plot(X, y_pred, label="Regression Line")

plt.xlabel("X")
plt.ylabel("Y")
plt.title("Linear Regression using Scikit-learn")
plt.legend()

plt.show()
# Out:
# Intercept (b0): 12.204233513320126
# Slope (b1): 0.7143924179327259
